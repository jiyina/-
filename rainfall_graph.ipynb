# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyina/-/blob/main/rainfall_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt

# %%
rainfall_df = pd.read_excel('/content/drive/My Drive/HSBDC excel files/nga-rainfall-subnat-5ytd sorted (1).xlsx')

# %%
yield_df = pd.read_csv('/content/drive/My Drive/HSBDC excel files/cassava & corn yield 1961-2023 - Sheet1 (1).csv')

# %%
rainfall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6660 entries, 0 to 6659
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6660 non-null   datetime64[ns]
#  1   adm_level       6660 non-null   int64
#  2   adm_id          6660 non-null   int64
#  3   PCODE           6660 non-null   object
#  4                   6660 non-null   int64
#  5   rfh             6660 non-null   float64
#  6   rfh_avg         6660 non-null   float64
#  7   r1h             6660 non-null   float64
#  8   r1h_avg         6660 non-null   float64
#  9   r3h             6660 non-null   float64
#  10  r3h_avg         6660 non-null   float64
#  11  rfq             6660 non-null   float64
#  12  r1q             6660 non-null   float64
#  13  r3q             6660 non-null   float64
#  14  version         6660 non-null   object
#  15  year (sorted)   6660 non-null   int64
#  16  month (sorted)  6660 non-null   int64
# ...

# %%
rainfall_df.keys()
# Out:
# Index(['date', 'adm_level', 'adm_id', 'PCODE', ' ', 'rfh', 'rfh_avg', 'r1h',
#        'r1h_avg', 'r3h', 'r3h_avg', 'rfq', 'r1q', 'r3q', 'version',
#        'year (sorted)', 'month (sorted)', 'day (sorted)', 'region'],
#       dtype='object')

# %%
x_benue = rainfall_df['date'].iloc[1982:2160]
y_benue = rainfall_df['r1h'].iloc[1982:2160]

x_ebonyi = rainfall_df['date'].iloc[542:720]
y_ebonyi = rainfall_df['r1h'].iloc[542:720]

# %%
plt.plot(x_benue, y_benue, color= 'blue')
plt.plot(x_ebonyi, y_ebonyi, color= 'orange')
plt.title('Benue vs Ebonyi rainfall')
# Out:
# Text(0.5, 1.0, 'Benue vs Ebonyi rainfall')
